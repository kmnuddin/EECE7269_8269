# %%
import pandas as pd
import numpy as np

import statsmodels.formula.api as sm

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
X_train = pd.read_csv('used car/X_train.csv')
y_train = pd.read_csv('used car/y_train.csv')

X_test = pd.read_csv('used car/X_test.csv')
y_test = pd.read_csv('used car/test_label/y_test.csv')

df = X_train.copy()
df['price'] = y_train['price']
df
# Out:
#       carID     brand      model  year transmission  mileage fuelType    tax  \
# 0     13207    hyundi   Santa Fe  2019    Semi-Auto     4223   Diesel  145.0
# 1     17314  vauxhall        GTC  2015       Manual    47870   Diesel  125.0
# 2     12342      audi        RS4  2019    Automatic     5151   Petrol  145.0
# 3     13426        vw   Scirocco  2016    Automatic    20423   Diesel   30.0
# 4     16004     skoda      Scala  2020    Semi-Auto     3569   Petrol  145.0
# ...     ...       ...        ...   ...          ...      ...      ...    ...
# 4955  16898      merc   GL Class  2015    Automatic    24314   Diesel  125.0
# 4956  14416       bmw   6 Series  2017    Automatic    18000   Diesel  145.0
# 4957  15453        vw         CC  2015       Manual    84932   Diesel   30.0
# 4958  14666      audi         A7  2017    Semi-Auto    30150   Diesel  145.0
# 4959  15135      merc        SLK  2014    Automatic    40230   Diesel  150.0
#
#        mpg  engineSize  price
# ...

# %%
cols = ['mileage', 'tax', 'mpg', 'engineSize', 'price']

fig, axes = plt.subplots(ncols=5, figsize=(15, 4))


for ax, col in zip(axes, cols):
    sns.kdeplot(data=df, x=col, ax=ax)
    
fig.tight_layout()
cols.remove('price')

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 8))


for ax, col in zip(axes.flatten(), cols):
    sns.scatterplot(data=df, x=col, y='price', ax=ax)
    
fig.tight_layout()

# %%
df['log_mileage'] = df['mileage'].apply(np.log)
sns.scatterplot(data=df, x='log_mileage', y='price')

# %% [markdown]
# ### Forward Selection

# %%
lm1 = sm.ols(formula='price ~ log_mileage', data=df).fit()
print(lm1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.198
# Model:                            OLS   Adj. R-squared:                  0.198
# Method:                 Least Squares   F-statistic:                     1225.
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):          4.35e-240
# Time:                        22:13:45   Log-Likelihood:                -54629.
# No. Observations:                4960   AIC:                         1.093e+05
# Df Residuals:                    4958   BIC:                         1.093e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    6.139e+04   1103.169     55.647      0.000    5.92e+04    6.36e+04
# ...

# %%
lm2 = sm.ols(formula='price ~ mileage', data=df).fit()
print(lm2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.229
# Model:                            OLS   Adj. R-squared:                  0.229
# Method:                 Least Squares   F-statistic:                     1474.
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):          1.45e-282
# Time:                        22:13:46   Log-Likelihood:                -54531.
# No. Observations:                4960   AIC:                         1.091e+05
# Df Residuals:                    4958   BIC:                         1.091e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.149e+04    292.349    107.709      0.000    3.09e+04    3.21e+04
# ...

# %%
lm3 = sm.ols(formula='price ~ mileage + mpg', data=df).fit()
print(lm3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.250
# Model:                            OLS   Adj. R-squared:                  0.250
# Method:                 Least Squares   F-statistic:                     827.1
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):          1.11e-310
# Time:                        22:13:46   Log-Likelihood:                -54462.
# No. Observations:                4960   AIC:                         1.089e+05
# Df Residuals:                    4957   BIC:                         1.090e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.468e+04    395.504     87.690      0.000    3.39e+04    3.55e+04
# ...

# %%
lm4 = sm.ols(formula='price ~ mileage + mpg + engineSize', data=df).fit()
print(lm4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.621
# Method:                 Least Squares   F-statistic:                     2714.
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):               0.00
# Time:                        22:13:46   Log-Likelihood:                -52766.
# No. Observations:                4960   AIC:                         1.055e+05
# Df Residuals:                    4956   BIC:                         1.056e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    926.5478    559.627      1.656      0.098    -170.569    2023.664
# ...

# %% [markdown]
# #### Introducing categorical variable

# %%
df = pd.get_dummies(df, columns=['transmission'], drop_first=True)
df
# Out:
#       carID     brand      model  year  mileage fuelType    tax   mpg  \
# 0     13207    hyundi   Santa Fe  2019     4223   Diesel  145.0  39.8
# 1     17314  vauxhall        GTC  2015    47870   Diesel  125.0  60.1
# 2     12342      audi        RS4  2019     5151   Petrol  145.0  29.1
# 3     13426        vw   Scirocco  2016    20423   Diesel   30.0  57.6
# 4     16004     skoda      Scala  2020     3569   Petrol  145.0  47.1
# ...     ...       ...        ...   ...      ...      ...    ...   ...
# 4955  16898      merc   GL Class  2015    24314   Diesel  125.0  56.6
# 4956  14416       bmw   6 Series  2017    18000   Diesel  145.0  51.4
# 4957  15453        vw         CC  2015    84932   Diesel   30.0  60.1
# 4958  14666      audi         A7  2017    30150   Diesel  145.0  62.8
# 4959  15135      merc        SLK  2014    40230   Diesel  150.0  56.5
#
#       engineSize  price  log_mileage  transmission_Manual  transmission_Other  \
# ...

# %%
formula = 'price ~ mileage + mpg + engineSize + transmission_Manual + transmission_Other + transmission_Semi-Auto'
lm5 = sm.ols(formula=formula, data=df).fit()
print(lm5.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/.virtualenvs/dl4cv/lib/python3.7/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# ~/.virtualenvs/dl4cv/lib/python3.7/site-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>
#
# NameError: name 'transmission_Semi' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-11-13ea50b71866> in <module>
# ...
